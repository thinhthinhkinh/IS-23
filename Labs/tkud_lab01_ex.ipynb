# %% [markdown]
# # Lab 01 - Bài tập

# %% [markdown]
# ## PYTHON

# %% [markdown]
# 1. Viết chương trình nhập vào số nguyên n (n>0). In ra các số nguyên tố từ 1..n

# %%
def is_prime(num):
    if num < 2:
        return False
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            return False
    return True

def print_primes(n):
    for num in range(1, n + 1):
        if is_prime(num):
            print(num)


n = int(input("Nhập vào số nguyên dương n (n > 0): "))
if n > 0:
    print("Các số nguyên tố từ 1 đến", n, "là:")
    print_primes(n)
else:
    print("Vui lòng nhập số nguyên dương.")
# Out:
# Nhập vào số nguyên dương n (n > 0): 11
# Các số nguyên tố từ 1 đến 11 là:
# 2
# 3
# 5
# 7
# 11

# %% [markdown]
# 2. Viết chương trình nhập vào số nguyên n có 3 chữ số. Tính tổng các chữ số của n

# %%
def sum_of_digits(n):
  if not 100 <= n <= 999:
    return "Số không hợp lệ. Vui lòng nhập số nguyên có 3 chữ số."

  total = 0
  while n > 0:
    digit = n % 10
    total += digit
    n //= 10
  return total

n = int(input("Nhập vào số nguyên n có 3 chữ số: "))
result = sum_of_digits(n)
print("Tổng các chữ số của", n, "là:", result)
# Out:
# Nhập vào số nguyên n có 3 chữ số: 333
# Tổng các chữ số của 333 là: 9

# %% [markdown]
# 3. Viết chương trình nhập vào một dãy các số nguyên được cách nhau bởi khoảng trắng (VD: 32 8 4 6 9...) lưu vào python ở dạng mảng. Thực hiện
#
# - Xuất mảng
# - Tính tổng các phần tử của mảng
# - Tìm số lớn nhất
# - Tìm số bé nhất
# - Sắp xếp mảng theo thứ tự giảm dần
# - In ra các số chẵn trong mảng

# %%
input_string = input("Nhập vào một dãy các số nguyên (cách nhau bởi khoảng trắng): ")
array = list(map(int, input_string.split()))

print("Mảng đã nhập:", array)

total_sum = sum(array)
print("Tổng các phần tử của mảng:", total_sum)

max_number = max(array)
print("Số lớn nhất trong mảng:", max_number)


min_number = min(array)
print("Số bé nhất trong mảng:", min_number)

sorted_array = sorted(array, reverse=True)
print("Mảng sau khi sắp xếp theo thứ tự giảm dần:", sorted_array)

even_numbers = [num for num in array if num % 2 == 0]
print("Các số chẵn trong mảng:", even_numbers)
# Out:
# Nhập vào một dãy các số nguyên (cách nhau bởi khoảng trắng): 4 5 2 23 5 7 7 6 53
# Mảng đã nhập: [4, 5, 2, 23, 5, 7, 7, 6, 53]
# Tổng các phần tử của mảng: 112
# Số lớn nhất trong mảng: 53
# Số bé nhất trong mảng: 2
# Mảng sau khi sắp xếp theo thứ tự giảm dần: [53, 23, 7, 7, 6, 5, 5, 4, 2]
# Các số chẵn trong mảng: [4, 2, 6]

# %% [markdown]
# 4. Viết chương trình yêu cầu người dùng nhập họ tên. Hiển thị tên người dùng sau khi đã chuẩn hóa. Biết rằng tên đã chuẩn hóa là:
# - Ký tự đầu viết hoa
# - Không có khoảng trắng thừa
# - Không có ký tự đặc biệt

# %%
import re
def tenthuong(ten):
  ten= re.sub(r'[^a-zA-Z\s]', '', ten)
  ten =' '.join(ten.split()).title()
  return ten
nhapngdung = input("Nhap ho ten: ")
tenthuong = tenthuong(nhapngdung)

print("Ten da chuan hoa: ", tenthuong)
# Out:
# Nhap ho ten: pham vo truong thinh
# Ten da chuan hoa:  Pham Vo Truong Thinh

# %% [markdown]
# 5. Viết chương trình nhập vào một số nguyên dương (n>0). Cho biết n có phải là số đối xứng hay không? Biết số đối xứng là số viết xuôi hay viết ngược đều như nhau

# %%
n = int(input("Nhập vào một số nguyên dương: "))

if n <= 0:
    print("Vui lòng nhập một số nguyên dương.")
else:
  chuyendoi = str(n)
  if chuyendoi == chuyendoi[::-1]:
    print(n, "là số đối xứng.")
  else:
    print(n, "không phải là số đối xứng.")
# Out:
# Nhập vào một số nguyên dương: 363
# 363 là số đối xứng.

# %% [markdown]
# 6. Với số nguyên n nhất định, hãy viết chương trình hiển thị dictionary chứa các cặp (i, i*i) ; biết i có giá trị từ 1..n

# %%
n = int(input("Nhập vào số nguyên n: "))

dictionary = {}
for i in range(1, n + 1):
    dictionary[i] = i * i

print("Dictionary chứa các cặp (i, i*i):", dictionary)
# Out:
# Nhập vào số nguyên n: 3
# Dictionary chứa các cặp (i, i*i): {1: 1, 2: 4, 3: 9}

# %% [markdown]
# 7. Viết chương trình tìm tất cả các số chia hết cho 7 nhưng không phải bội số của 5, nằm trong đoạn 2000 và 3200 (tính cả 2000 và 3200). Các số thu được sẽ được in thành chuỗi trên một dòng, cách nhau bằng dấu phẩy

# %%
result = []
for i in range(2000, 3201):
  if i % 7 == 0 and i % 5 != 0:
    result.append(str(i))
print(','.join(result))
# Out:
# 2002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,2289,2296,2303,2317,2324,2331,2338,2352,2359,2366,2373,2387,2394,2401,2408,2422,2429,2436,2443,2457,2464,2471,2478,2492,2499,2506,2513,2527,2534,2541,2548,2562,2569,2576,2583,2597,2604,2611,2618,2632,2639,2646,2653,2667,2674,2681,2688,2702,2709,2716,2723,2737,2744,2751,2758,2772,2779,2786,2793,2807,2814,2821,2828,2842,2849,2856,2863,2877,2884,2891,2898,2912,2919,2926,2933,2947,2954,2961,2968,2982,2989,2996,3003,3017,3024,3031,3038,3052,3059,3066,3073,3087,3094,3101,3108,3122,3129,3136,3143,3157,3164,3171,3178,3192,3199

# %% [markdown]
# 8. Viết chương trình chấp nhận một chuỗi số, phân tách bằng dấu phẩy từ giao diện điều khiển, tạo ra một List và một tuple chứa mọi số.
#
#     Ví dụ:
#
#     ```
#     Đầu vào được cung cấp là '34,67,55,33,12,98' thì đầu ra là:
#
#     [34, 67, 55, 33, 12, 98]
#     (34, 67, 55, 33, 12, 98)
#     ```

# %%
nhapchuoi = input("Nhập một chuỗi số, phân tách bằng dấu phẩy: ")
list_so = [int(num) for num in nhapchuoi.split(',')]

tuple_so = tuple(list_so)
print("List chứa các số:", list_so)
print("Tuple chứa các số:", tuple_so)
# Out:
# Nhập một chuỗi số, phân tách bằng dấu phẩy: 34,67,55,33,12,98
# List chứa các số: [34, 67, 55, 33, 12, 98]
# Tuple chứa các số: (34, 67, 55, 33, 12, 98)

# %% [markdown]
# 9. Viết hàm nhận vào một danh sách các số nguyên. Hãy viết hàm trả về một danh sách gồm các số không trùng nhau trong danh sách ban đầu

# %%
def songuyen(nhap):
  songuyen = list(set(nhap))
  return songuyen
so = [1,2,3,4,5,6,6,7,8,8,9,9,2,3,9]
kqua = songuyen(so)
print("Danh sach cac so khong trung nhau: ",kqua)
# Out:
# Danh sach cac so khong trung nhau:  [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# 10. Viết hàm có tham số đầu vào là một list L có các phần tử là chuỗi. Hãy tạo ra một dictionary D mã hóa, với mỗi một phần tử trong L được mã hóa thành một con số (theo thứ tự từ 0 tăng dần lên 1 đơn vị). Sau đó trả về list đã được mã hóa
#
#     Ví dụ:
#
#     ```
#     Cho L = ["đen","vàng","xanh","vàng","xanh","đỏ","hồng"]
#
#     Xây dựng dictionary mã hóa:
#     D = {'đen':0,'vàng':1,'xanh':2,'đỏ':3,'hồng':4}
#
#     Trả về List mã hóa:
#     L_mahoa = [0, 1, 2, 1, 2, 3, 4]
#     ```

# %%
def mahoa(L):

    D = {}
    for item in L:
        if item not in D:
            D[item] = len(D)

    L_mahoa = [D[item] for item in L]

    return D, L_mahoa

L = ["đen", "vàng", "xanh", "vàng", "xanh", "đỏ", "hồng"]
D = {'đen':0,'vàng':1,'xanh':2,'đỏ':3,'hồng':4}
print("Danh sách đã mã hóa:", L_mahoa)
# Out:
# Danh sách đã mã hóa: [0, 1, 2, 1, 2, 3, 4]

# %% [markdown]
# ---
